# %%
import numpy as np
import pandas as pd

# %%
url = 'https://s3-us-west-2.amazonaws.com/learn-assets.galvanize.com/gSchool/ds-curriculum/sql-block/universities.csv'
uni = pd.read_csv(url, sep = '\t', delimiter=",")

uni
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
uni.head()
# Out:
#                                       name  \
# 0  A T Still University of Health Sciences
# 1             Abilene Christian University
# 2     Abraham Baldwin Agricultural College
# 3                          Academy College
# 4     Academy for Five Element Acupuncture
#
#                                              address                 Website  \
# 0        800 W Jefferson, Kirksville, Missouri 63501            WWW.ATSU.EDU
# 1            1600 Campus Court, Abilene, Texas 79699             www.acu.edu
# 2         2802 Moore Hwy, Tifton, Georgia 31793-2601            www.abac.edu
# 3  1101 E. 78th Street, Suite 100, Minneapolis, M...  www.academycollege.edu
# 4         305 SE 2nd Ave, Gainesville, Florida 32601   www.acupuncturist.edu
#
#                                                 Type    Size
# 0                     4-year, Private not-for-profit  3480.0
# 1                     4-year, Private not-for-profit  4669.0
# ...

# %%
uni.shape
# Out:
# (2907, 5)

# %%
uni.describe
# Out:
# <bound method NDFrame.describe of                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# ...

# %%
uni.columns
# Out:
# Index(['name', 'address', 'Website', 'Type', 'Size'], dtype='object')

# %%
#this is the not as clean way to get the mean with sorted values, but it still works
mean= uni.groupby(['Type'])['Size'].mean().sort_values()
mean
# Out:
# Type
# 4-year, primarily associate's, Private for-profit          934.380597
# 4-year, primarily associate's, Private not-for-profit     1129.413793
# 4-year, Private not-for-profit                            2399.885696
# 4-year, Private for-profit                                3504.501859
# 4-year, primarily associate's, Public                     6889.366197
# 4-year, Public                                           11478.913765
# Name: Size, dtype: float64

# %%
#here i've set median equal to a variable so I can call it elsewhere in short hand
med= uni.groupby(['Type'])['Size'].median()
med
# Out:
# Type
# 4-year, Private for-profit                                730.0
# 4-year, Private not-for-profit                           1206.0
# 4-year, Public                                           7669.0
# 4-year, primarily associate's, Private for-profit         564.5
# 4-year, primarily associate's, Private not-for-profit     768.0
# 4-year, primarily associate's, Public                    3558.0
# Name: Size, dtype: float64

# %%
#I call it here in shorthand and sort the values in a clean way
med=med.sort_values()
med
# Out:
# Type
# 4-year, primarily associate's, Private for-profit         564.5
# 4-year, Private for-profit                                730.0
# 4-year, primarily associate's, Private not-for-profit     768.0
# 4-year, Private not-for-profit                           1206.0
# 4-year, primarily associate's, Public                    3558.0
# 4-year, Public                                           7669.0
# Name: Size, dtype: float64

# %%
#uni[["address"]] = uni["city"].str.split(pat=",", expand=True)

location_uni = uni[['address']].apply(lambda x: pd.Series(str(x).split(',')))
location_uni
# Out:
#                                               address
# 0                       0             800 W Jefferson
# 1                                          Kirksville
# 2    Missouri 63501\n1                 1600 Campus...
# 3                                             Abilene
# 4          Texas 79699\n2              2802 Moore Hwy
# 5                                              Tifton
# 6     Georgia 31793-2601\n3       1101 E. 78th Street
# 7                                           Suite 100
# 8                                         Minneapolis
# 9                 M...\n4              305 SE 2nd Ave
# 10                                        Gainesville
# 11   Florida 32601\n                              ...
# 12                                        Los Angeles
# 13              Ca...\n2903             1125 E 8th St
# 14                                               York
# 15    Nebraska 68467-2699\n2904       Country Club Rd
# ...

# %%
x = lambda x: pd.Series([i for i in x.split(',')])
rev = uni['address'].apply(x)
rev
# Out:
#                                   0             1                         2  \
# 0                   800 W Jefferson    Kirksville            Missouri 63501
# 1                 1600 Campus Court       Abilene               Texas 79699
# 2                    2802 Moore Hwy        Tifton        Georgia 31793-2601
# 3               1101 E. 78th Street     Suite 100               Minneapolis
# 4                    305 SE 2nd Ave   Gainesville             Florida 32601
# ...                             ...           ...                       ...
# 2902  13315 W. Washington Boulevard   Los Angeles          California 90066
# 2903                  1125 E 8th St          York       Nebraska 68467-2699
# 2904                Country Club Rd          York   Pennsylvania 17403-3651
# 2905           One University Plaza    Youngstown           Ohio 44555-0001
# 2906          320 South Main Street     Haverhill       Massachusetts 01835
#
#                           3    4    5
# ...

# %%
address1 = uni['address']
address1 = address1.str.strip()
address1 = address1.str.split(',', expand=True) #expand puts results into two separate columns
address2 = address1.rename(columns={0:'street', 1:'city', 2:'state zip'})
address2
# Out:
#                              street          city                 state zip  \
# 0                   800 W Jefferson    Kirksville            Missouri 63501
# 1                 1600 Campus Court       Abilene               Texas 79699
# 2                    2802 Moore Hwy        Tifton        Georgia 31793-2601
# 3               1101 E. 78th Street     Suite 100               Minneapolis
# 4                    305 SE 2nd Ave   Gainesville             Florida 32601
# ...                             ...           ...                       ...
# 2902  13315 W. Washington Boulevard   Los Angeles          California 90066
# 2903                  1125 E 8th St          York       Nebraska 68467-2699
# 2904                Country Club Rd          York   Pennsylvania 17403-3651
# 2905           One University Plaza    Youngstown           Ohio 44555-0001
# 2906          320 South Main Street     Haverhill       Massachusetts 01835
#
#                           3     4     5
# ...

# %%
address3 = address2['state zip'].str.rsplit(' ',1, expand=True)
address3= address3.rename(columns={0:'state', 1: 'zip'})
address3
# Out:
#                state          zip
# 0           Missouri        63501
# 1              Texas        79699
# 2            Georgia   31793-2601
# 3                     Minneapolis
# 4            Florida        32601
# ...              ...          ...
# 2902      California        90066
# 2903        Nebraska   68467-2699
# 2904    Pennsylvania   17403-3651
# 2905            Ohio   44555-0001
# 2906   Massachusetts        01835
#
# [2907 rows x 2 columns]

# %%
data1= pd.concat([uni,address2,address3],axis=1)
data1
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
data1 = data1.drop(columns = ['address','state zip', 3, 4, 5])
data1
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                      Website  \
# 0               WWW.ATSU.EDU
# 1                www.acu.edu
# 2               www.abac.edu
# 3     www.academycollege.edu
# 4      www.acupuncturist.edu
# ...                      ...
# 2902           www.yosan.edu
# 2903           www.york.edu/
# ...
